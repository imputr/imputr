# %%
import pandas as pd
import numpy as np
from imputr import AutoImputer

df = pd.read_csv('datasets/DigiDB_digimonlist.csv')

# Create random missing values
np.random.seed(100)
mask = np.random.choice([True, False], size=df.shape)
df.mask(mask, inplace=True)

imputer = AutoImputer(df)
imputed_df = imputer.impute()

# %%
imputed_df
# Out:
#            Number            Digimon Stage     Type Attribute     Memory  \
# index
# 0      124.642175          Silphymon  Baby     Free   Neutral   2.000000
# 1      124.642175          Silphymon  Mega     Free      Dark  11.916496
# 2        3.000000            Punimon  Mega    Virus   Neutral  11.916496
# 3      124.642175            Botamon  Baby     Free   Neutral   2.000000
# 4      124.642175          Silphymon  Baby     Free      Dark   2.000000
# ...           ...                ...   ...      ...       ...        ...
# 244    124.642175          Silphymon  Mega    Virus      Wind  11.916496
# 245    246.000000          Silphymon  Mega  Vaccine      Fire  11.916496
# 246    247.000000  MirageGaogamon BM  Mega    Virus     Light  11.916496
# 247    124.642175          Silphymon  Mega    Virus      Wind  20.000000
# 248    249.000000          Silphymon  Mega     Data     Plant  20.000000
#
#        Equip Slots     Lv 50 HP     Lv50 SP    Lv50 Atk    Lv50 Def  \
# index
# ...
